# %%
import numpy as np
import matplotlib.pyplot as plt
N = 10000
n = 1800
a = 0
b = 1
k = 40
A = (a + b) / 2
D = ((b - a) ** 2) / 12

random_numbers = np.random.uniform(a, b, size=(N, n))

Sn = random_numbers.sum(axis=1)
An = n * A
Dn = n * D
X = (Sn - An) / np.sqrt(Dn)


x = np.linspace(-4, 4, 1000)
y = (1/np.sqrt(2*np.pi)) * np.exp(-0.5*x**2)


plt.plot(x, y, 'r-', lw=3)
plt.hist(X, density=True, bins=k)
# Out:
# (array([0.00101694, 0.00050847, 0.00203388, 0.00355929, 0.00661011,
#         0.01474562, 0.02999971, 0.03610134, 0.05847401, 0.08440596,
#         0.10576168, 0.14440537, 0.18813376, 0.23237062, 0.28220064,
#         0.33864077, 0.38694539, 0.37575906, 0.41541969, 0.38745386,
#         0.39813172, 0.36253885, 0.28525146, 0.23237062, 0.19474387,
#         0.15864252, 0.12813435, 0.08491443, 0.05084696, 0.03660981,
#         0.02389807, 0.01728797, 0.01016939, 0.00101694, 0.00254235,
#         0.00152541, 0.00050847, 0.        , 0.00050847, 0.00050847]),
#  array([-3.64727684, -3.45060826, -3.25393968, -3.05727109, -2.86060251,
#         -2.66393393, -2.46726535, -2.27059677, -2.07392819, -1.87725961,
#         -1.68059103, -1.48392245, -1.28725387, -1.09058529, -0.89391671,
#         -0.69724813, -0.50057955, -0.30391097, -0.10724239,  0.08942619,
#          0.28609477,  0.48276335,  0.67943193,  0.87610051,  1.07276909,
# ...
